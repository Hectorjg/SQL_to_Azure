# %%
#Images from Azura

# %%
# Libraries
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# Create a Data Factory to process the data: firststorage

# %%
data_factory = mpimg.imread('C:/Users/ASUS/Desktop/Hector/SQL_to_Azure/Images_from_Azura/data_factory.png')
fig, ax = plt.subplots(figsize=(15, 10))
ax.imshow(data_factory)
ax.axis('off')
plt.show()

# %%
## Enter into the new Data factory and open Azure Data Factory Studio

# %%
# Create a Azure Blob Storage; project1
# Create a DataBase; projectDatabase

# %%
storage = mpimg.imread('C:/Users/ASUS/Desktop/Hector/SQL_to_Azure/Images_from_Azura/storage_and_DB.png')
fig, ax = plt.subplots(figsize=(15, 10))
ax.imshow(storage)
ax.axis('off')
plt.show()

# %%
# Create the Delimeted text DataBase for the .csv file

# %%
Dtext = mpimg.imread('C:/Users/ASUS/Desktop/Hector/SQL_to_Azure/Images_from_Azura/clean_data_path.png')
fig, ax = plt.subplots(figsize=(15, 10))
ax.imshow(Dtext)
ax.axis('off')
plt.show()

# %%
# Create a get_file to track the .csv file

# %%
get_file = mpimg.imread('C:/Users/ASUS/Desktop/Hector/SQL_to_Azure/Images_from_Azura/get_file.png')
fig, ax = plt.subplots(figsize=(15, 10))
ax.imshow(get_file)
ax.axis('off')
plt.show()

# %%
# A DataBase to connect it with the desire SQL DataBse; connectDB

# %%
connectDB = mpimg.imread('C:/Users/ASUS/Desktop/Hector/SQL_to_Azure/Images_from_Azura/connectDB.png')
fig, ax = plt.subplots(figsize=(15, 10))
ax.imshow(connectDB)
ax.axis('off')
plt.show()

# %%
# Set up a "Get matadata" and a "Copy data" and link them manually, then Debug to upload the .csv from
# the storage into the desire DataBase

# %%
get_copy_upload = mpimg.imread('C:/Users/ASUS/Desktop/Hector/SQL_to_Azure/Images_from_Azura/get_copy_upload.png')
fig, ax = plt.subplots(figsize=(15, 10))
ax.imshow(get_copy_upload)
ax.axis('off')
plt.show()

# %%
# Check that the .csv was uploaded correctly into the desire DataBase; projects
# And it was converted to  SQL

# %%
checking_database = mpimg.imread('C:/Users/ASUS/Desktop/Hector/SQL_to_Azure/Images_from_Azura/checking_database.png')
fig, ax = plt.subplots(figsize=(15, 10))
ax.imshow(checking_database)
ax.axis('off')
plt.show()
